# %% [markdown]
# <a href="https://colab.research.google.com/github/jeunefeu/dogecoin-analysis/blob/main/dogecoin_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DOGECOIN, History, MarketCap Evolution...**

# %% [markdown]
# ![51b54d13d65d8ee3773ce32da03e1fa220-dogecoin.rsquare.w1200.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Dogecoin was officially launched on December 6, 2013, as a "joke",or by what we call now as a "memecoin", its purpose was to make fun of the new cryptocurrency payment technologies, making it the first memecoin ever which will later influence other memecoins to appear such as Shiba Inu...
# # However, the "joke" went too far, let's find out why and how...

# %%
# Importing pandas
import pandas as pd

# Importing matplotlib and setting aesthetics for plotting later.
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('fivethirtyeight')

# Reading datasets/coinmarketcap_06122017.csv into pandas
df = pd.read_csv("coin_Dogecoin.csv")

# Let's take a look at the data
df.head()
# Out:
#    SNo      Name Symbol  ...     Close  Volume     Marketcap
# 0    1  Dogecoin   DOGE  ...  0.000205     0.0  1.509085e+06
# 1    2  Dogecoin   DOGE  ...  0.000269     0.0  2.169688e+06
# 2    3  Dogecoin   DOGE  ...  0.000362     0.0  3.188943e+06
# 3    4  Dogecoin   DOGE  ...  0.001162     0.0  1.115034e+07
# 4    5  Dogecoin   DOGE  ...  0.000704     0.0  7.284337e+06
#
# [5 rows x 10 columns]

# %% [markdown]
# ### MarketCap evolution over the years

# %%
# Selecting the 'id' and the 'market_cap_usd' columns
market_cap_doge = df[["SNo", "Date", "Marketcap"]]

# Checking the number of values
market_cap_doge.count()
# Out:
# SNo          2760
# Date         2760
# Marketcap    2760
# dtype: int64

# %%
# By year
market_cap_doge["Date"] = pd.to_datetime(market_cap_doge["Date"])
# We take the mean ofeach year
market_cap_doge_year = market_cap_doge["Marketcap"].groupby(market_cap_doge["Date"].dt.year).mean()
market_cap_doge_year
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Date
# 2013    6.444175e+06
# 2014    3.020221e+07
# 2015    1.426257e+07
# 2016    2.471941e+07
# 2017    1.775101e+08
# 2018    4.990701e+08
# 2019    3.080947e+08
# 2020    3.441145e+08
# 2021    2.325315e+10
# Name: Marketcap, dtype: float64

# %%
# Plotting the results
plt.figure(figsize=(16,6))
market_cap_doge_year.plot(x = "Date", y = "Marketcap", kind = "line")
